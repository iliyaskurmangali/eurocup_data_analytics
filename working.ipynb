# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('Uefa Euro Cup All Matches.csv')

# %%
def determine_winner(row):
    if row['HomeTeamGoals'] > row['AwayTeamGoals']:
        return "home_win"
    elif row['HomeTeamGoals'] < row['AwayTeamGoals']:
        return "away_team_win"
    else:
        return "draw"

# %%
home_counts = df['HomeTeamName'].value_counts().reset_index()
home_counts.columns = ['Team', 'HomeCount']

away_counts = df['AwayTeamName'].value_counts().reset_index()
away_counts.columns = ['Team', 'AwayCount']

# Merge counts to get unique rows
team_counts = pd.merge(home_counts, away_counts, on='Team', how='outer').fillna(0)
team_counts['Total'] = team_counts['HomeCount'] + team_counts['AwayCount']

unique_teams = team_counts['Team'].unique()

# Print all unique team names
for team in unique_teams:
    print(team)
# Out:
# Albania
# Austria
# Belgium
# Bulgaria
# CIS
# Croatia
# Czech Republic
# Czechoslovakia
# Denmark
# England
# FR Yugoslavia
# France
# Germany
# Greece
# Hungary
# Iceland
# Italy
# Latvia
# Netherlands
# Northern Ireland
# Norway
# Poland
# Portugal
# Republic of Ireland
# Romania
# Russia
# Scotland
# Slovakia
# Slovenia
# Soviet Union
# Spain
# Sweden
# Switzerland
# Turkey
# Ukraine
# Wales
# West Germany
# Yugoslavia
#  Albania
#  Austria
#  Belgium
#  Bulgaria
#  CIS
#  Croatia
#  Czech Republic
#  Czechoslovakia
#  Denmark
#  England
#  FR Yugoslavia
#  France
#  Germany
#  Greece
#  Hungary
#  Iceland
#  Italy
#  Latvia
#  Netherlands
#  Northern Ireland
#  Norway
#  Poland
#  Portugal
#  Republic of Ireland
#  Romania
#  Russia
#  Scotland
#  Slovakia
#  Slovenia
#  Soviet Union
#  Spain
#  Sweden
#  Turkey
#  Ukraine
#  Wales
#  West Germany
#  Yugoslavia
#   Switzerland

# %%
# Function to determine match result based on goals
def determine_winner(row):
    if row['HomeTeamGoals'] > row['AwayTeamGoals']:
        return "home_win"
    elif row['HomeTeamGoals'] < row['AwayTeamGoals']:
        return "away_win"
    else:
        return "draw"

# Apply determine_winner function to create MatchResult column
df['MatchResult'] = df.apply(determine_winner, axis=1)

def team_statistics(df, team1, team2):
    # Filter matches where team1 or team2 is either HomeTeamName or AwayTeamName
    team1_home = df[df['HomeTeamName'].str.contains(team1) | df['AwayTeamName'].str.contains(team1)]
    team2_home = df[df['HomeTeamName'].str.contains(team2) | df['AwayTeamName'].str.contains(team2)]

    # Calculate number of matches played between team1 and team2
    team1_vs_team2 = team1_home[(team1_home['HomeTeamName'].str.contains(team1) & team1_home['AwayTeamName'].str.contains(team2)) |
                                (team1_home['AwayTeamName'].str.contains(team1) & team1_home['HomeTeamName'].str.contains(team2))]

    # Calculate number of matches where team2 played against team1
    team2_vs_team1 = team2_home[(team2_home['HomeTeamName'].str.contains(team2) & team2_home['AwayTeamName'].str.contains(team1)) |
                                (team2_home['AwayTeamName'].str.contains(team2) & team2_home['HomeTeamName'].str.contains(team1))]

    total_matches = len(team1_vs_team2)

    team1_wins = team1_vs_team2.loc[(team1_vs_team2['HomeTeamName'].str.contains(team1) & team1_vs_team2['MatchResult'] == 'home_win') |
                                   (team1_vs_team2['AwayTeamName'].str.contains(team1) & team1_vs_team2['MatchResult'] == 'away_win')].shape[0]

    team2_wins = team2_vs_team1.loc[(team1_vs_team2['HomeTeamName'].str.contains(team2) & team1_vs_team2['MatchResult'] == 'home_win') |
                                   (team1_vs_team2['AwayTeamName'].str.contains(team2) & team1_vs_team2['MatchResult'] == 'away_win')].shape[0]

    team1_goals = team1_vs_team2.loc[team1_vs_team2['HomeTeamName'].str.contains(team1), 'HomeTeamGoals'].sum() + \
                  team1_vs_team2.loc[team1_vs_team2['AwayTeamName'].str.contains(team1), 'AwayTeamGoals'].sum()

    team2_goals = team1_vs_team2.loc[team1_vs_team2['HomeTeamName'].str.contains(team2), 'HomeTeamGoals'].sum() + \
                  team1_vs_team2.loc[team1_vs_team2['AwayTeamName'].str.contains(team2), 'AwayTeamGoals'].sum()

    return total_matches, team1_wins, team2_wins, team1_goals, team2_goals
    return total_matches, team1_wins, team2_wins, team1_goals, team2_goals


# Define the teams for which you want to calculate statistics
team1 = 'Germany'
team2 = 'France'

# Calculate statistics for team1 vs team2
total_matches, team1_wins, team2_wins, team1_goals, team2_goals = team_statistics(df, team1, team2)

# Print the results
print(f"Total matches between {team1} and {team2}: {total_matches}")
print(f"{team1} wins: {team1_wins}")
print(f"{team2} wins: {team2_wins}")
print(f"Total goals scored by {team1}: {team1_goals}")
print(f"Total goals scored by {team2}: {team2_goals}")
# Out:
# Total matches between Germany and France: 1
# Germany wins: 0
# France wins: 0
# Total goals scored by Germany: 0
# Total goals scored by France: 2

# %%
def determine_winner(row):
    if row['HomeTeamGoals'] > row['AwayTeamGoals']:
        return "home_win"
    elif row['HomeTeamGoals'] < row['AwayTeamGoals']:
        return "away_win"
    else:
        return "draw"

# Apply determine_winner function to create MatchResult column
df['MatchResult'] = df.apply(determine_winner, axis=1)

def team_statistics(df, team1, team2):
    # Filter matches where team1 or team2 is either HomeTeamName or AwayTeamName
    team1_home = df[df['HomeTeamName'].str.contains(team1) | df['AwayTeamName'].str.contains(team1)]
    team2_home = df[df['HomeTeamName'].str.contains(team2) | df['AwayTeamName'].str.contains(team2)]

    # Calculate number of matches played between team1 and team2
    team1_vs_team2 = team1_home[(team1_home['HomeTeamName'].str.contains(team1) & team1_home['AwayTeamName'].str.contains(team2)) |
                                (team1_home['AwayTeamName'].str.contains(team1) & team1_home['HomeTeamName'].str.contains(team2))]

    # Calculate number of matches where team2 played against team1
    team2_vs_team1 = team2_home[(team2_home['HomeTeamName'].str.contains(team2) & team2_home['AwayTeamName'].str.contains(team1)) |
                                (team2_home['AwayTeamName'].str.contains(team2) & team2_home['HomeTeamName'].str.contains(team1))]

    total_matches = len(team1_vs_team2)

    team1_wins = len(team1_vs_team2.loc[((team1_vs_team2['HomeTeamName'].str.contains(team1)) & (team1_vs_team2['MatchResult'].str.contains('home_win'))) |
                                       ((team1_vs_team2['AwayTeamName'].str.contains(team1)) & (team1_vs_team2['MatchResult'].str.contains('away_win')))])

    team2_wins = len(team1_vs_team2.loc[((team1_vs_team2['HomeTeamName'].str.contains(team2)) & (team1_vs_team2['MatchResult'].str.contains('home_win'))) |
                                       ((team1_vs_team2['AwayTeamName'].str.contains(team2)) & (team1_vs_team2['MatchResult'].str.contains('away_win')))])

    # Calculate total goals scored by team1 and team2
    team1_goals = team1_vs_team2.loc[team1_vs_team2['HomeTeamName'].str.contains(team1), 'HomeTeamGoals'].sum() + \
                  team1_vs_team2.loc[team1_vs_team2['AwayTeamName'].str.contains(team1), 'AwayTeamGoals'].sum()

    team2_goals = team1_vs_team2.loc[team1_vs_team2['HomeTeamName'].str.contains(team2), 'HomeTeamGoals'].sum() + \
                  team1_vs_team2.loc[team1_vs_team2['AwayTeamName'].str.contains(team2), 'AwayTeamGoals'].sum()

    return total_matches, team1_wins, team2_wins, team1_goals, team2_goals

# Define the teams for which you want to calculate statistics
team1 = 'Czechoslovakia'
team2 = 'Soviet Union'

# Calculate statistics for team1 vs team2
total_matches, team1_wins, team2_wins, team1_goals, team2_goals = team_statistics(df, team1, team2)

# Print the results
print(f"Total matches between {team1} and {team2}: {total_matches}")
print(f"{team1} wins: {team1_wins}")
print(f"{team2} wins: {team2_wins}")
print(f"Total goals scored by {team1}: {team1_goals}")
print(f"Total goals scored by {team2}: {team2_goals}")
# Out:
# Total matches between Czechoslovakia and Soviet Union: 1
# Czechoslovakia wins: 0
# Soviet Union wins: 1
# Total goals scored by Czechoslovakia: 0
# Total goals scored by Soviet Union: 3

# %%
df
# Out:
#                           Date   Time     HomeTeamName   AwayTeamName  \
# 0     6 July 1960 (1960-07-06)  20:00          France      Yugoslavia
# 1     6 July 1960 (1960-07-06)  21:30  Czechoslovakia    Soviet Union
# 2     9 July 1960 (1960-07-09)  21:30  Czechoslovakia          France
# 3    10 July 1960 (1960-07-10)  21:30    Soviet Union      Yugoslavia
# 4    17 June 1964 (1964-06-17)  20:00           Spain         Hungary
# ..                         ...    ...              ...            ...
# 281   2 July 2016 (2016-07-02)  21:00         Germany           Italy
# 282   3 July 2016 (2016-07-03)  21:00          France         Iceland
# 283   6 July 2016 (2016-07-06)  21:00        Portugal           Wales
# 284   7 July 2016 (2016-07-07)  21:00         Germany          France
# 285  10 July 2016 (2016-07-10)  21:00        Portugal          France
#
#      HomeTeamGoals  AwayTeamGoals                 Stage  \
# 0                4              5           Semi-finals
# 1                0              3           Semi-finals
# 2                2              0  Third place play-off
# 3                2              1                 Final
# 4                2              1           Semi-finals
# ..             ...            ...                   ...
# 281              1              1        Quarter-finals
# 282              5              2        Quarter-finals
# 283              2              0           Semi-finals
# 284              0              2           Semi-finals
# 285              1              0                 Final
#
#                     SpecialWinConditions                    Stadium  \
# 0                                    NaN           Parc des Princes
# 1                                    NaN            Stade Vélodrome
# 2                                    NaN            Stade Vélodrome
# 3    Soviet Union  win after extra time            Parc des Princes
# 4           Spain  win after extra time           Santiago Bernabéu
# ..                                   ...                        ...
# 281       Germany  win on Penalities 6–5  Nouveau Stade de Bordeaux
# 282                                  NaN            Stade de France
# 283                                  NaN    Parc Olympique Lyonnais
# 284                                  NaN            Stade Vélodrome
# 285      Portugal  win after extra time             Stade de France
#
#                   City  Attendance  Year MatchResult
# 0                Paris       26370  1960    away_win
# 1            Marseille       25184  1960    away_win
# 2            Marseille        9438  1960    home_win
# 3                Paris       17966  1960    home_win
# 4               Madrid       34713  1964    home_win
# ..                 ...         ...   ...         ...
# 281           Bordeaux       38764  2016        draw
# 282        Saint-Denis       76833  2016    home_win
# 283   Décines-Charpieu       55679  2016    home_win
# 284          Marseille       64078  2016    away_win
# 285        Saint-Denis       75868  2016    home_win
#
# [286 rows x 13 columns]
